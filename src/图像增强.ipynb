# %%
from PIL import Image
from PIL import ImageFilter
import os
import shutil
import re

# %%
import time
import picamera
import numpy as np
import cv2

with picamera.PiCamera() as camera:
    camera.resolution = (320, 240)
    camera.framerate = 24
    time.sleep(2)
    image = np.empty((240 * 320 * 3,), dtype=np.uint8)
    # save as bgr format for OpenCV
    camera.capture(image, 'bgr')
    image = image.reshape((240, 320, 3))
    cv2.imshow("img", image)
    if(cv2.waitKey(0) == ord('q')):
        exit(0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-89f0e85b3d6f> in <module>
#       2 import picamera
#       3 import numpy as np
# ----> 4 import cv2
#       5
#       6 with picamera.PiCamera() as camera:
#
# ModuleNotFoundError: No module named 'cv2'

# %%
os.system('raspistill -w 300 -h 300 -o test2.jpg')
img = Image.open('test2.jpg')
img#.convert('L').save('g.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0xB3E72B70>

# %%
r,g,b = img.split()

# %%
a=list(r.getdata())

# %%
c = 0
for i,v in enumerate(a):
    if v > 240:
        c += 1
c
# Out:
# 0

# %%
r
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0xAF3AAFD0>

# %%
g
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0xAF39F1F0>

# %%
b
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0xAF39F210>
